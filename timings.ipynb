BM=256 BK=512 BN=512 | Time=1.26967 s | GFLOPS=13.0608\
BM=512 BK=32 BN=32 | Time=1.04 s | GFLOPS=15.9452\
BM=512 BK=32 BN=64 | Time=1.00048 s | GFLOPS=16.575\
BM=512 BK=32 BN=128 | Time=0.986321 s | GFLOPS=16.8129\
BM=512 BK=32 BN=256 | Time=0.979689 s | GFLOPS=16.9267\
BM=512 BK=32 BN=512 | Time=1.07008 s | GFLOPS=15.4969\
BM=512 BK=64 BN=32 | Time=0.981358 s | GFLOPS=16.898\
BM=512 BK=64 BN=64 | Time=0.958431 s | GFLOPS=17.3022\
BM=512 BK=64 BN=128 | Time=0.94797 s | GFLOPS=17.4931\
BM=512 BK=64 BN=256 | Time=1.00478 s | GFLOPS=16.5041\
BM=512 BK=64 BN=512 | Time=1.2777 s | GFLOPS=12.9788\
BM=512 BK=128 BN=32 | Time=0.956993 s | GFLOPS=17.3282\
BM=512 BK=128 BN=64 | Time=0.940165 s | GFLOPS=17.6383\
BM=512 BK=128 BN=128 | Time=0.98477 s | GFLOPS=16.8394\
BM=512 BK=128 BN=256 | Time=1.25802 s | GFLOPS=13.1818\
BM=512 BK=128 BN=512 | Time=1.255 s | GFLOPS=13.2135\
BM=512 BK=256 BN=32 | Time=0.944657 s | GFLOPS=17.5544\
BM=512 BK=256 BN=64 | Time=1.00699 s | GFLOPS=16.4678\
BM=512 BK=256 BN=128 | Time=1.25505 s | GFLOPS=13.213\
BM=512 BK=256 BN=256 | Time=1.2475 s | GFLOPS=13.2929\
BM=512 BK=256 BN=512 | Time=1.24854 s | GFLOPS=13.2819\
BM=512 BK=512 BN=32 | Time=1.09013 s | GFLOPS=15.2119\
BM=512 BK=512 BN=64 | Time=1.24813 s | GFLOPS=13.2862\
BM=512 BK=512 BN=128 | Time=1.24434 s | GFLOPS=13.3267\
BM=512 BK=512 BN=256 | Time=1.24852 s | GFLOPS=13.282\
BM=512 BK=512 BN=512 | Time=1.2537 s | GFLOPS=13.2272"

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Parse lines
pattern = r"BM=(\d+)\s+BK=(\d+)\s+BN=(\d+)\s+\|\s+Time=[\d\.]+ s\s+\|\s+GFLOPS=([\d\.]+)"
data = []

for match in re.finditer(pattern, txt):
    BM, BK, BN, GFLOPS = match.groups()
    data.append({
        "BM": int(BM),
        "BK": int(BK),
        "BN": int(BN),
        "GFLOPS": float(GFLOPS)
    })

# Convert to DataFrame
df = pd.DataFrame(data)

# Plot GFLOPS vs BN for fixed BM/BK
plt.figure(figsize=(8,5))
for (BM, BK), group in df.groupby(["BM","BK"]):
    plt.plot(group["BN"], group["GFLOPS"], marker='o', label=f"BM={BM} BK={BK}")

plt.xlabel("BN")
plt.ylabel("GFLOPS")
plt.title("Matrix multiplication GFLOPS vs BN")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd

# df is your DataFrame
BM_unique = sorted(df["BM"].unique())
BN_unique = sorted(df["BN"].unique())

BM_grid, BN_grid = np.meshgrid(BM_unique, BN_unique)
GFLOPS_grid = np.zeros_like(BM_grid, dtype=float)

for i, BN in enumerate(BN_unique):
    for j, BM in enumerate(BM_unique):
        row = df[(df["BM"]==BM) & (df["BN"]==BN)]
        GFLOPS_grid[i, j] = row["GFLOPS"].values[0] if not row.empty else np.nan

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(BM_grid, BN_grid, GFLOPS_grid, cmap='viridis')
ax.set_xlabel('BM')
ax.set_ylabel('BN')
ax.set_zlabel('GFLOPS')
ax.set_title('GFLOPS vs BM and BN')
plt.show()

# %%
import seaborn as sns
pivot_table = df.pivot(index="BN", columns="BM", values="GFLOPS")
plt.figure(figsize=(8,6))
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap="viridis")
plt.title("GFLOPS Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 import seaborn as sns
# ----> 2 pivot_table = df.pivot(index="BN", columns="BM", values="GFLOPS")
#       3 plt.figure(figsize=(8,6))
#       4 sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap="viridis")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:9346, in DataFrame.pivot(self, columns, index, values)
#    9339 @Substitution("")
#    9340 @Appender(_shared_docs["pivot"])
#    9341 def pivot(
#    9342     self, *, columns, index=lib.no_default, values=lib.no_default
#    9343 ) -> DataFrame:
#    9344     from pandas.core.reshape.pivot import pivot
# -> 9346     return pivot(self, index=index, columns=columns, values=values)
#
# ...

# %%
# parse text
matches = re.findall(pattern, txt)

rows = []
for BM, BK, BN, GFLOPS in matches:
    BM = int(BM)
    BK = int(BK)
    BN = int(BN)
    GFLOPS = float(GFLOPS)
    size = BM*BK + BK*BN + BM*BN
    rows.append({"BM": BM, "BK": BK, "BN": BN, "GFLOPS": GFLOPS, "Size": size})

df = pd.DataFrame(rows)

# plot GFLOPS vs Size metric
plt.figure(figsize=(8,5))
plt.plot(df["Size"], df["GFLOPS"], marker='*')
plt.xlabel("BM*BK + BK*BN + BM*BN")
plt.ylabel("GFLOPS")
plt.title("GFLOPS vs Block-Size Metric")
plt.grid(True)
plt.show()

# %%
for _, group in df.groupby("Size"):
    plt.plot(group["Size"], group["GFLOPS"], marker="o")
plt.legend()
# Out:
# /var/folders/mw/0_yqnltn6rbg1msz5s15_vgc0000gn/T/ipykernel_83463/453425189.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#reorder based on Gflops
df = df.sort_values("GFLOPS", ascending=False)
#plot
plt.figure(figsize=(8,5))
plt.plot(df["Size"], df["GFLOPS"], marker='o')
plt.xlabel("BM*BK + BK*BN + BM*BN")
plt.ylabel("GFLOPS")
plt.title("GFLOPS vs Block-Size Metric")
plt.grid(True)
plt.show()

# %%
display(df)
# Out:
#       BM   BK   BN    GFLOPS    Size
# 236  512  128   64  17.63830  106496
# 240  512  256   32  17.55440  155648
# 232  512   64  128  17.49310  106496
# 211  256  128   64  17.40360   57344
# 235  512  128   32  17.32820   86016
# ..   ...  ...  ...       ...     ...
# 18    16  128  128  10.93000   20480
# 22    16  256   64  10.68940   21504
# 24    16  256  256   9.61793   73728
# 23    16  256  128   9.60197   38912
# 19    16  128  256   9.51435   38912
#
# [250 rows x 5 columns]
